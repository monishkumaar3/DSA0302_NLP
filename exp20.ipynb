# %%
import spacy

# Load the SpaCy English model
nlp = spacy.load("en_core_web_sm")

# Sentences for dependency parsing
sentences = [
    "John and Mary went to the store.",
    "The big brown dog chased the small black cat."
]

# Perform dependency parsing using SpaCy
for sentence in sentences:
    doc = nlp(sentence)

    # Display the token dependencies in each sentence
    print(f"Sentence: '{sentence}'")
    print("Token Dependencies:")
    for token in doc:
        print(f"{token.text} --{token.dep_}--> {token.head.text}")
    print()
# Out:
# Sentence: 'John and Mary went to the store.'
# Token Dependencies:
# John --nsubj--> went
# and --cc--> John
# Mary --conj--> John
# went --ROOT--> went
# to --prep--> went
# the --det--> store
# store --pobj--> to
# . --punct--> went
#
# Sentence: 'The big brown dog chased the small black cat.'
# Token Dependencies:
# The --det--> dog
# big --amod--> dog
# brown --amod--> dog
# dog --nsubj--> chased
# chased --ROOT--> chased
# the --det--> cat
# small --amod--> cat
# black --amod--> cat
# cat --dobj--> chased
# . --punct--> chased
